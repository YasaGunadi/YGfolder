# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('sampling 1 plays.csv', on_bad_lines='skip')
# Out:
# C:\Users\user\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df.head()
# Out:
#                                      hash_content_id  \
# 0  0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 1  01ddda2f8667719625bd0afa58537fd95a166c93233b8b...
# 2  01ddda2f8667719625bd0afa58537fd95a166c93233b8b...
# 3  01e34cb2658d0461f220bda493cb38427eef7de1e23e6e...
# 4  01e34cb2658d0461f220bda493cb38427eef7de1e23e6e...
#
#                                         hash_play_id  \
# 0  0162f124f5bd61592d9bca6aaa3b1b6097a00b62ef33c9...
# 1  5f6c722782c919a9cb6254e94086462a6c34794dc741b6...
# 2  66c32aa6aa6a63f7d85d1bd1b8b6b295477c88794888d8...
# 3  38976454aec1c7ff4ca0a35df8821db29227443352e705...
# 4  4b4ee4aa4c37519250aa6efbd78e789b40d976474a1c37...
#
#                                        hash_visit_id  \
# 0  27dfffe2bb74f8767caeb64ac4c92e9eaf4b11a28ef7e1...
# 1  90b2b454e70a2c13cf9e8ca987d7c4f914c7d819532c5d...
# 2  f79cab25855841a83e6aa01eccbf3d167491a868977b77...
# 3  f23800acfeede429803cb2a1380ca7652067fb35d079a8...
# ...

# %%
#EDA (explorarity data analyst)

# %%
#melihat informasi data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106811 entries, 0 to 106810
# Data columns (total 41 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   hash_content_id    106811 non-null  object
#  1   hash_play_id       106811 non-null  object
#  2   hash_visit_id      106811 non-null  object
#  3   hash_watcher_id    106811 non-null  object
#  4   hash_film_id       5818 non-null    object
#  5   hash_event_id      106811 non-null  object
#  6   is_login           106811 non-null  bool
#  7   playback_location  106811 non-null  object
#  8   platform           106811 non-null  object
#  9   play_time          106811 non-null  object
#  10  end_time           106811 non-null  object
#  11  referrer           101050 non-null  object
#  12  average_bitrate    101865 non-null  float64
#  13  bitrate_range      106811 non-null  object
#  14  total_bytes        106811 non-null  int64
# ...

# %%
#melihat type data
df['referrer_group']
# Out:
# 0         liputan6
# 1          bolanet
# 2          bolanet
# 3         liputan6
# 4         liputan6
#             ...
# 106806      others
# 106807    liputan6
# 106808      others
# 106809        bola
# 106810      others
# Name: referrer_group, Length: 106811, dtype: object

# %%
#melihat banyaknya yang duplikat data
df.duplicated().sum()
# Out:
# 0

# %%
#melihat data yg null

df.isnull().sum()
# Out:
# hash_content_id           0
# hash_play_id              0
# hash_visit_id             0
# hash_watcher_id           0
# hash_film_id         100993
# hash_event_id             0
# is_login                  0
# playback_location         0
# platform                  0
# play_time                 0
# end_time                  0
# referrer               5761
# average_bitrate        4946
# bitrate_range             0
# total_bytes               0
# buffer_duration           0
# referrer_group            0
# completed             38937
# utm_source           106724
# utm_medium           106724
# utm_campaign         106773
# player_name            3267
# has_ad                    0
# flash_version         34850
# os_name               33725
# os_version              405
# browser_name          33666
# browser_version       36038
# app_name                  0
# autoplay              38960
# is_premium                0
# app_version           72129
# city                 106811
# ...

# %%
#delete duplikat data berdasarkan utm_medium
df.drop_duplicates(subset='utm_medium')
# Out:
#                                          hash_content_id  \
# 0      0096dafb1049ee942e8e7cbad5abf4a46dc92e3995caac...
# 1056   bf2af47c9d722b2429b9a31d9b4a9e3b361b90e3955c61...
# 1393   5843570dbdfa3b413ea3656abd5c1f0ab712112e3df2c9...
# 3792   46775fdcb42399722762896de65f146c4f44bf8f5891ba...
# 7776   e2d4213d55b3d35c2df77c8f98d18759212d3edea863ba...
# 12123  0e4ae59199cba12347c4eb31b1e9f433a1607f6d0ecf05...
# 45251  7cce13ed8253b9271c3a820a45a08ad23918ee4baeb593...
#
#                                             hash_play_id  \
# 0      0162f124f5bd61592d9bca6aaa3b1b6097a00b62ef33c9...
# 1056   b0378b61d5b207d844e9a6523a774c2ee7a943861cbe27...
# 1393   f3c23962e51eec23f7dc8144c2bd8a14f8906ed94c6ec6...
# 3792   860b99f25e7c4fc9dd8133bcba1e6795124face3402b34...
# 7776   1207e8a30de3df5acb0a7e407c131ddb32ec331e05a6e7...
# 12123  f815ade688b2da761ff7b366271b46540af01090ef4d64...
# 45251  a067b9bfa949d0fbb5e898c010a3c2b324f14e7a9c12cd...
#
# ...

# %%
#membuat visualisasi tabel batang
df['play_duration'].plot()
# Out:
# <AxesSubplot:>

# %%
# jika data kategorical melihat descriptip statistik
df.describe(include='object')
# Out:
#                                           hash_content_id  \
# count                                              106811
# unique                                              10422
# top     fc56dbc6d4652b315b86b71c8d688c1ccdea9c5f1fd077...
# freq                                                 8101
#
#                                              hash_play_id  \
# count                                              106811
# unique                                             106811
# top     0162f124f5bd61592d9bca6aaa3b1b6097a00b62ef33c9...
# freq                                                    1
#
#                                             hash_visit_id  \
# count                                              106811
# unique                                             106479
# top     bf819a5a315dfd1374213b79e5f1703eacdc01babb4fe7...
# freq                                                    4
#
#                                           hash_watcher_id  \
# ...

# %%
#outliers analyst?
